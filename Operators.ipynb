# %% [markdown]
# <a href="https://colab.research.google.com/github/Bindusri2294/Bindhu/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ARITHMETIC OPERATORS

# %%
x=5
y=1
print (x+y)
# Out:
# 6

# %%
x=5
y=1
print (x-y)
# Out:
# 4

# %%
x=5
y=1
print (x*y)
# Out:
# 5

# %%
x=5
y=1
print (x/y)
# Out:
# 5.0

# %%
x=5
y=1
print (x%y)
# Out:
# 0

# %%
x=5
y=2
print (x**y)
# Out:
# 25

# %%
x=5
y=1
print (x//y)
# Out:
# 5

# %%
ASSIGNMENT OPERATORS

# %%
x=5
x+=3
print (x)
# Out:
# 8

# %%
x=5
x+=3
print (x)

# %%
x=5
x-=3
print (x)
# Out:
# 2

# %%
x=5
x*=3
print (x)
# Out:
# 15

# %%
x=5
x/=3
print (x)
# Out:
# 1.6666666666666667

# %%
x=5
x%=3
print (x)
# Out:
# 2

# %%
x=5
x//=3
print (x)
# Out:
# 1

# %%
x=5
x**=3
print (x)
# Out:
# 125

# %%
x=5
x&=3
print (x)
# Out:
# 1

# %%
x=5
x^=3
print (x)
# Out:
# 6

# %%
x=5
x>>=3
print (x)
# Out:
# 0

# %%
x=5
x<<=3
print (x)
# Out:
# 40

# %%
PYTHON CAMPARISION OPERATORS

# %%
x=5
y=3
print (x==y)
# Out:
# False

# %%
x=5
y=3
print (x!=y)
# Out:
# True

# %%
x=5
y=3
print (x<y)
# Out:
# False

# %%
x=5
y=3
print (x>y)
# Out:
# True

# %%
x=5
y=3
print (x>=y)
# Out:
# True

# %%
x=5
y=3
print (x<=y)
# Out:
# False

# %%
PYTHON LOGICAL OPERATORS

# %%
x=5
print (x>3&x<10)
# Out:
# True

# %%
x=5
print (x>3&x<4)
# Out:
# True
