# %% [markdown]
# <a href="https://colab.research.google.com/github/Bindusri2294/Bindhu/blob/main/Boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=20
b=30
if b>a:
   print ("b is greater than a")
else :
   print ("b is  less than a")
# Out:
# b is greater than a

# %%
a=20
b=30
if b>a:
   print ("b is greater than a")
else :
   print ("b is  not greater than a")
# Out:
# b is greater than a

# %%
a=40
b=30
if b>a:
   print ("a is greater than b")
else :
   print ("b is  less than a")
# Out:
# b is  less than a

# %%
print (bool("Hello"))
print (bool(15))
# Out:
# True
# True

# %%
X="hello"
Y=15
print (bool(X))
print (bool(Y))
# Out:
# True
# True
