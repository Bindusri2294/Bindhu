# %% [markdown]
# <a href="https://colab.research.google.com/github/Bindusri2294/Bindhu/blob/main/CRT_TRAINING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
VARIABLE DECLARATION

# %%
name = "Bindu"
age = "20"
price=99.

# %%
Name ="Bindu"
Age = "20"
Price=99.

# %%
A="BINDU"
B=444
C="KIET"
D=10.00
E=5+2j
F=True
print(A)
print(type(A))
# Out:
# BINDU
# <class 'str'>

# %%
A="BINDU"
B=444
C="KIET"
D=10.00
E=5+2j
F=True
print(F)
print(type(F))
# Out:
# True
# <class 'bool'>

# %%
A="BINDU"
B=444
C="KIET"
D=10.00
E=5+2j
F="True"
print(F)
print(type(F))
# Out:
# True
# <class 'str'>

# %%
A="BINDU"
B=444
C="KIET"
D=10.00
E=5+2j
F=True
print(D)
print(type(D))
# Out:
# 10.0
# <class 'float'>

# %%
A="BINDU"
B=444
C="KIET"
D=10.00
E=5+2j
F="FALSE"
print(A)
print(type(A))
print(B)
print(type(B))
print(C)
print(type(C))
print(D)
print(type(D))
print(E)
print(type(E))
print(F)
print(type(F))
# Out:
# BINDU
# <class 'str'>
# 444
# <class 'int'>
# KIET
# <class 'str'>
# 10.0
# <class 'float'>
# (5+2j)
# <class 'complex'>
# FALSE
# <class 'str'>

# %%
A="BINDU"
B=444
C="KIET"
D=10.00
E=5+2j
F=False
print(F)
print(type(F))
# Out:
# False
# <class 'bool'>

# %%
num=int(input("enter a num:"))
print(num)
# Out:
# enter a num:20
# 20

# %%
num=float(input("Enter a num:"))
print(num)
# Out:
# Enter a num:20.0
# 20.0

# %%
name=input("what is your name")
greeting="hello"
print(greeting + " "+ name)
# Out:
# what is your namebindu
# hello bindu

# %%
name=input("what is your name")
b="hello"
print(b + " "+ name)
# Out:
# what is your namebindu
# hello bindu
