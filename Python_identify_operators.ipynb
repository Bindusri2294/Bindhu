# %% [markdown]
# <a href="https://colab.research.google.com/github/Bindusri2294/Bindhu/blob/main/Python_identify_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=["apple ","banana"]
y=["apple ","banana"]
z=x
print (x is z)
print (x is y)
print (x==y)
# Out:
# True
# False
# True

# %%
x=["apple ","banana"]
y=["apple ","banana"]
z=x
print (x is not  z)
print (x is not  y)
print (x!=y)
# Out:
# False
# True
# False

# %%
PYTHON MEMBER SHIP OPERATORS

# %%
x=["apple ","banana"]
print ("pineapple "not in x)
# Out:
# True

# %%
x=["apple ","banana"]
print ("apple"not in x)
# Out:
# True
